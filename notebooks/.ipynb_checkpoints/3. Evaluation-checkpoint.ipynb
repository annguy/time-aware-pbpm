# %% [markdown]
# # Enhancing Customer Experience- Deep Learning for Predictive Business Process Monitoring
# Evaluation
#
#
# This notebook shows how to:
#     1. Evaluate the performance

# %%
#Install Dependencies--> Refer to 1. Train.py
#Import Libraries
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '1' 
import tensorflow as tf
from src.Data.Datahandler import Datahandler
from src.Features.ComputeCW import *
from src.Features.Preprocess import *
from src.Features.Preprocess_Context import *
from src.Hyperparameter.Hyperparameter import *
from src.Models.Model import *
from src.Models.Time_Model import *
from src.Models.TLSTM_Models import *
from src.Models.Test import NextStep, Remaining_Step
from src.Evaluates.Evaluate import Nextstep_eval,Remainstep_eval
from tensorboard.plugins.hparams import api as hp
import pickle
from src.Models.Test_Context import *

# %% [markdown]
# # Test Results Load
#
#     1. Evaluation type
#     2. Reading the test result files

# %%
os.chdir('..')
#Restart the kernel and re-run the whole notebook incase the directory location is not correct

Eval=input('For Nextstep_Evaluation Enter 1, For Remainingstep_Evaluation Enter 2:  ')
print('  ')
filename = input("Enter the next_step file name of the format:Results/filename.csv' : ") 
print('  ')
# Out:
# For Nextstep_Evaluation Enter 1, For Remainingstep_Evaluation Enter 2:  2
#
# Enter the next_step file name of the format:Results/filename.csv' : Results/suffix_and_remaining_time_8.Baselinehelpdesk.csv

# %%
if Eval == '1':
    try:
        Ev=Nextstep_eval(filename)
        Ev.read()
        act_time=input("For time evaluations Enter 1, For activity related evaluations enter 2, Enter 3 for both: ")
        if act_time=='1':
            Ev.time()
        elif act_time=='2':
            Ev.activities()
        elif act_time=='3':
            Ev.time()
            Ev.activities()
    except IOError as e:
        errno, strerror = e.args
        print("I/O error({0}): {1}".format(errno,strerror))     
elif Eval== '2':
    try:
        Ev=Remainstep_eval(filename)
        Ev.read()
        act_time=input("For time evaluations Enter 1, For activity related evaluations enter 2, Enter 3 for both: ")
        if act_time=='1':
            Ev.time()
        elif act_time=='2':
            Ev.activities()
        elif act_time=='3':
            Ev.time()
            Ev.activities()
    except IOError as e:
        errno, strerror = e.args
        print("I/O error({0}): {1}".format(errno,strerror))
# Out:
#    CaseID  Prefix length Groud truth Predicted  Levenshtein  Damerau  \
# 0    3087              2          Â§        Â§          1.0      1.0
# 1    3088              2    Â©ÂªÂ©Â§      Â©Â§          0.5      0.5
# 2    3089              2        ÂªÂ§        Â§          0.5      0.5
# 3    3090              2          Â§        Â§          1.0      1.0
# 4    3091              2        Â§Â§        Â§          0.5      0.5
#
#     Jaccard  Ground truth times  Predicted times  RMSE           MAE
# 0  1.000000              256462     55453.479807   NaN  2.010085e+05
# 1  0.666667             1888363     82007.196948   NaN  1.806356e+06
# 2  0.500000              520705     70623.162182   NaN  4.500818e+05
# 3  1.000000                1800     60498.491367   NaN  5.869849e+04
# 4  1.000000              511776     59296.146208   NaN  4.524799e+05
# For time evaluations Enter 1, For activity related evaluations enter 2, Enter 3 for both: 3
#
# Prefix_Length 2
# Number of Cases= 1200
# Average Error= 6.25512533221486 Days
#
# Prefix_Length 3
# Number of Cases= 445
# Average Error= 7.845968836122122 Days
#
# Prefix_Length 4
# Number of Cases= 195
# Average Error= 6.164205620601843 Days
#
# Prefix_Length 5
# Number of Cases= 89
# Average Error= 6.273135916709596 Days
#
# Prefix_Length 6
# Number of Cases= 39
# Average Error= 5.232983314750325 Days
#
# Prefix_Length 7
# Number of Cases= 10
# Average Error= 6.359230227527367 Days
#
# Prefix_Length 8
# Number of Cases= 7
# Average Error= 3.7837666155561536 Days
#
# Prefix_Length 9
# Number of Cases= 4
# Average Error= 5.9593304388440975 Days
#
# Prefix_Length 10
# Number of Cases= 3
# Average Error= 2.8337615740740745 Days
#
# Prefix_Length 11
# Number of Cases= 1
# Average Error= 1.274212962962963 Days
#
# Overall Average Error in Days 5.19817208393634
# Overall Weighted Average Erorr in Days 6.565837210555284
# Prefix_Length 2
# Number of Cases= 1200
# Accuracy= 82.40433201058201 %
#
# Prefix_Length 3
# Number of Cases= 445
# Accuracy= 57.17478152309613 %
#
# Prefix_Length 4
# Number of Cases= 195
# Accuracy= 61.06959706959707 %
#
# Prefix_Length 5
# Number of Cases= 89
# Accuracy= 41.939539860888175 %
#
# Prefix_Length 6
# Number of Cases= 39
# Accuracy= 57.82051282051282 %
#
# Prefix_Length 7
# Number of Cases= 10
# Accuracy= 43.66666666666667 %
#
# Prefix_Length 8
# Number of Cases= 7
# Accuracy= 38.0952380952381 %
#
# Prefix_Length 9
# Number of Cases= 4
# Accuracy= 58.333333333333336 %
#
# Prefix_Length 10
# Number of Cases= 3
# Accuracy= 0.0 %
#
# Prefix_Length 11
# Number of Cases= 1
# Accuracy= 0.0 %
#
# Overall Accuracy 44.05040013799144
# Overall Weighted Accuracy 71.8318280648938

# %%
df=Ev.df
counter=[]
pre=[]
for i in df['Prefix length'].unique():
    #print('')
    #print('Prefix_Length',i )
    pre.append(i)
    x= df[df['Prefix length']==i]
    Wrong=x[x['Groud truth']!=x['Predicted']].count()[0]
    Correct=x[x['Groud truth']==x['Predicted']].count()[0]
    Total=x.count()[0]
    counter.append(Total)
    Accuracy=(Correct/Total)*100
g=plt.figure(figsize=[20,5])
plt.gcf().subplots_adjust(bottom=0.15)
plt.xticks(pre)
plot3=plt.plot(pre,counter,'--',marker='o',markerfacecolor='r',markersize=15)
plt.title('Sample distribution per prefix BPI12w',fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.grid()
plt.xlabel('Prefixsize',fontsize=20)
plt.ylabel('Number of Cases',fontsize=20)
plt.show()
